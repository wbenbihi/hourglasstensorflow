# %% [markdown]
# <center style="font-weight:bold;font-size:20px">wbenbihi/hourglasstensorlfow: Stacked Hourglass Network for Human Pose Estimation</center>

# %% [markdown]
# <center style="font-weight:bold;font-size:20px">Construct TF Dataset - First Iteration</center>

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.append(os.path.join('..'))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage.io import imread
from skimage.transform import resize
from utils import ROOT_PATH, load_configuration
sns.set()

# %% [markdown]
# ## Global Variables

# %%
ROOT_FOLDER = ROOT_PATH
DATA_FOLDER = 'data'
IMAGE_FOLDER = 'images'
LABELS_FILE = "MPII_DATASET_LABELS.csv"

# %%
CFG = load_configuration(os.path.join(ROOT_PATH, 'config', 'hpeDefault.yml'))

# %% [markdown]
# # Function definition

# %% [markdown]
# ## Numpy Functions

# %%
# define normalized 2D gaussian
def gaus2d(x=0, y=0, mx=0, my=0, sx=1, sy=1):
    return 1. / (2. * np.pi * sx * sy) * np.exp(-((x - mx)**2. / (2. * sx**2.) + (y - my)**2. / (2. * sy**2.)))

def generate_joint_gaussian(img, x, y, sx=1, sy=1):
    if np.isnan(x) or np.isnan(y):
        return np.zeros_like(img[:, :, -1])
    y_space = np.linspace(0, img.shape[0], img.shape[0])
    x_space = np.linspace(0, img.shape[1], img.shape[1])
    x_space, y_space = np.meshgrid(x_space, y_space) # get 2D variables instead of 1D
    z = gaus2d(x_space, y_space, x, y, sx, sy)
    return z

# %% [markdown]
# ## TensorFlow functions

# %%
# Image Reader
@tf.function
def tf_read_image(filename):
    image = tf.io.decode_jpeg(tf.io.read_file(filename), channels=3)
    return image

# %%
# Bivariate(2D) Gaussian
@tf.function
def tf_bivariate_normal_pdf(height, width, mx, my, sx, sy):
    X = tf.range(start=0., limit=tf.cast(width, tf.float32), delta=1.)
    Y = tf.range(start=0., limit=tf.cast(height, tf.float32), delta=1.)
    X, Y = tf.meshgrid(X, Y)
    R = tf.sqrt(((X-mx)**2/(sx**2)) + ((Y-my)**2)/(sy**2))
    Z = ((1. / (2 * np.pi) * tf.sqrt(sx*sy)) * tf.exp(-.5*R**2))
    return Z

# %%
# Single Heatmap generation
@tf.function
def tf_generate_heatmap(coord, image):
    shape = tf.shape(image, out_type=tf.dtypes.int32)
    height = shape[0]
    width = shape[1]
    if tf.reduce_all(tf.math.is_finite(coord)):
        x = coord[0] 
        y = coord[1]
        return tf_bivariate_normal_pdf(height, width, x, y, sx=10., sy=10.)
    else:
        return tf.zeros([height, width])

# Heatmaps generation iterator
@tf.function
def tf_heatmaps(coords, image):
    return tf.transpose(tf.map_fn(lambda x: tf_generate_heatmap(x, image), tf.cast(coords, tf.float32)), [1, 2, 0])

# %%
@tf.function
def tf_parse_dataset(filename, coords):
    images = tf_read_image(filename)
    heatmaps = tf_heatmaps(coords, images)
    return images, heatmaps

# %%
@tf.function
def tf_autopad(tensor):
    shape = tf.shape(tensor,out_type=tf.dtypes.int32)
    pad_x = tf.clip_by_value(
        shape[1] - shape[0],
        0,
        10000,
        name=None
    )
    pad_y = tf.clip_by_value(
        shape[0] - shape[1],
        0,
        10000,
        name=None
    )
    padded_tensor = tf.pad(
        tensor,
        [
            [pad_x // 2, pad_x //2],
            [pad_y // 2, pad_y //2],
            [0, 0],
        ]
    )
    return padded_tensor

@tf.function
def tf_resize(tensor, size):
    return tf.image.resize(tensor, [size, size])

@tf.function
def tf_resize_input(tensor):
    return tf.image.resize(tensor, [CFG.data.input_size, CFG.data.input_size])

@tf.function
def tf_resize_output(tensor):
    return tf.image.resize(tensor, [CFG.data.output_size, CFG.data.output_size])
    
@tf.function
def tf_preprocess(images, heatmaps):
    images = tf_autopad(images)
    heatmaps = tf_autopad(heatmaps)
    images = tf_resize(images, CFG.data.input_size)
    heatmaps = tf_resize(heatmaps, CFG.data.output_size)
    return images, heatmaps

# %% [markdown]
# ## Viz functions

# %%
def aggregate_heatmaps(heatmaps):
    return heatmaps.sum(axis=0)

def plot_hVSimg(img, heatmaps, factor=1, figsize=(12, 7)):
    if len(heatmaps.shape) == 3:
        hm = aggregate_heatmaps(heatmaps)
    else:
        hm = heatmaps
    
    if len(img.shape) == 3:
        hm = np.expand_dims(hm, axis=-1)
    hm = hm / hm.max()
    
    plt.figure(figsize=figsize)
    plt.imshow(hm + img/(255.0*factor))
    plt.grid(b=None)

# %% [markdown]
# # Main Code

# %% [markdown]
# ## Read Labels

# %%
mpii_dataset_df = pd.read_csv(os.path.join(ROOT_FOLDER, DATA_FOLDER, LABELS_FILE), sep=';')

# %%
mpii_dataset_df
# Out:
#        imgidx          image  frame_sec  vididx  is_train  ridx   x1    x2  \
# 0           0  037454012.jpg         -1      -1         0     0  NaN   NaN
# 1           1  095071431.jpg         -1      -1         0     0  NaN   NaN
# 2           1  095071431.jpg         -1      -1         0     1  NaN   NaN
# 3           2  073199394.jpg         -1      -1         0     0  NaN   NaN
# 4           3  059865848.jpg         -1      -1         0     0  NaN   NaN
# ...       ...            ...        ...     ...       ...   ...  ...   ...
# 40934   24984  084761779.jpg        158     793         1     4  0.0  76.0
# 40935   24985  092025825.jpg         -1      -1         0     0  NaN   NaN
# 40936   24985  092025825.jpg         -1      -1         0     1  NaN   NaN
# 40937   24986  053686627.jpg         -1      -1         0     0  NaN   NaN
# 40938   24986  053686627.jpg         -1      -1         0     1  NaN   NaN
#
#           y1     y2  ...  joint_14_id  joint_14_is_visible  joint_15_x  \
# 0        NaN    NaN  ...          NaN                  NaN         NaN
# 1        NaN    NaN  ...          NaN                  NaN         NaN
# 2        NaN    NaN  ...          NaN                  NaN         NaN
# 3        NaN    NaN  ...          NaN                  NaN         NaN
# 4        NaN    NaN  ...          NaN                  NaN         NaN
# ...      ...    ...  ...          ...                  ...         ...
# 40934  135.0  216.0  ...          NaN                  NaN         NaN
# 40935    NaN    NaN  ...          NaN                  NaN         NaN
# 40936    NaN    NaN  ...          NaN                  NaN         NaN
# 40937    NaN    NaN  ...          NaN                  NaN         NaN
# 40938    NaN    NaN  ...          NaN                  NaN         NaN
#
#        joint_15_y  joint_15_id  joint_15_is_visible   video_list  \
# 0             NaN          NaN                  NaN          NaN
# 1             NaN          NaN                  NaN          NaN
# 2             NaN          NaN                  NaN          NaN
# 3             NaN          NaN                  NaN          NaN
# 4             NaN          NaN                  NaN          NaN
# ...           ...          ...                  ...          ...
# 40934         NaN          NaN                  NaN  GqxDyQ_TfZc
# 40935         NaN          NaN                  NaN          NaN
# 40936         NaN          NaN                  NaN          NaN
# 40937         NaN          NaN                  NaN          NaN
# 40938         NaN          NaN                  NaN          NaN
#
#              cat_name     act_name  act_id
# 0                 NaN          NaN      -1
# 1                 NaN          NaN      -1
# 2                 NaN          NaN      -1
# 3                 NaN          NaN      -1
# 4                 NaN          NaN      -1
# ...               ...          ...     ...
# 40934  transportation  pushing car     972
# 40935             NaN          NaN      -1
# 40936             NaN          NaN      -1
# 40937             NaN          NaN      -1
# 40938             NaN          NaN      -1
#
# [40939 rows x 81 columns]

# %%
train_df = mpii_dataset_df.query('is_train == 1')

# %% [markdown]
# ## Explore samples

# %% [markdown]
# ### Sanity checks

# %%
# Sanity Check - Look if every joint is in the roght columns
for i in range(16):
    print(f'Joint {i}\n',train_df[f'joint_{i}_id'].value_counts(), '\n')
# Out:
# Joint 0
#  0.0    20773
# Name: joint_0_id, dtype: int64
#
# Joint 1
#  1.0    24330
# Name: joint_1_id, dtype: int64
#
# Joint 2
#  2.0    28212
# Name: joint_2_id, dtype: int64
#
# Joint 3
#  3.0    28218
# Name: joint_3_id, dtype: int64
#
# Joint 4
#  4.0    24344
# Name: joint_4_id, dtype: int64
#
# Joint 5
#  5.0    20772
# Name: joint_5_id, dtype: int64
#
# Joint 6
#  6.0    28100
# Name: joint_6_id, dtype: int64
#
# Joint 7
#  7.0    28674
# Name: joint_7_id, dtype: int64
#
# Joint 8
#  8.0    28674
# Name: joint_8_id, dtype: int64
#
# Joint 9
#  9.0    28673
# Name: joint_9_id, dtype: int64
#
# Joint 10
#  10.0    28563
# Name: joint_10_id, dtype: int64
#
# Joint 11
#  11.0    28665
# Name: joint_11_id, dtype: int64
#
# Joint 12
#  12.0    28776
# Name: joint_12_id, dtype: int64
#
# Joint 13
#  13.0    28768
# Name: joint_13_id, dtype: int64
#
# Joint 14
#  14.0    28653
# Name: joint_14_id, dtype: int64
#
# Joint 15
#  15.0    28500
# Name: joint_15_id, dtype: int64

# %%
# Check for images with no joint
train_df.query(" and ".join([f'(joint_{i}_id.isna())' for i in range(16)]))
# Out:
#        imgidx          image  frame_sec  vididx  is_train  ridx      x1  \
# 2191     1367  090903252.jpg         60    2655         1     0  1412.0
# 3477     2248  059897851.jpg        428    2280         1     1  1388.0
# 5243     3174  007049195.jpg         63    1065         1     0   568.0
# 7758     4916  032783820.jpg         41    2528         1     1   793.0
# 8826     5602  012525123.jpg        159     927         1     1   607.0
# ...       ...            ...        ...     ...       ...   ...     ...
# 38482   23850  099879285.jpg         97     779         1     0   604.0
# 38484   23851  015883915.jpg        107     779         1     0   848.0
# 38703   23957  062020483.jpg        144       6         1     2    39.0
# 40587   24732  011387000.jpg         49    2718         1     0  1350.0
# 40588   24732  011387000.jpg         49    2718         1     1     4.0
#
#            x2     y1      y2  ...  joint_14_id  joint_14_is_visible  \
# 2191   1527.0    0.0    37.0  ...          NaN                  NaN
# 3477   1610.0  124.0   376.0  ...          NaN                  NaN
# 5243    636.0   43.0   119.0  ...          NaN                  NaN
# 7758    914.0  346.0   518.0  ...          NaN                  NaN
# 8826    654.0  166.0   231.0  ...          NaN                  NaN
# ...       ...    ...     ...  ...          ...                  ...
# 38482   861.0  529.0   881.0  ...          NaN                  NaN
# 38484  1085.0  557.0   863.0  ...          NaN                  NaN
# 38703    63.0  174.0   231.0  ...          NaN                  NaN
# 40587  1721.0  501.0   875.0  ...          NaN                  NaN
# 40588   330.0  623.0  1037.0  ...          NaN                  NaN
#
#        joint_15_x  joint_15_y  joint_15_id  joint_15_is_visible   video_list  \
# 2191          NaN         NaN          NaN                  NaN  wW1gyfLCEW4
# 3477          NaN         NaN          NaN                  NaN  oSPUMDPsz6k
# 5243          NaN         NaN          NaN                  NaN  Mrc0Y5x1UfU
# 7758          NaN         NaN          NaN                  NaN  thvlhJya6qg
# 8826          NaN         NaN          NaN                  NaN  JvpNDW4LYUE
# ...           ...         ...          ...                  ...          ...
# 38482         NaN         NaN          NaN                  NaN  GWnRhyOGvqA
# 38484         NaN         NaN          NaN                  NaN  GWnRhyOGvqA
# 38703         NaN         NaN          NaN                  NaN  -2uisU2cXqQ
# 40587         NaN         NaN          NaN                  NaN  xyFfCA34stw
# 40588         NaN         NaN          NaN                  NaN  xyFfCA34stw
#
#                 cat_name                                           act_name  \
# 2191   winter activities                                       dog sledding
# 3477          occupation  working in scene shop, theater actor, backstag...
# 5243              sports                             rope skipping, general
# 7758          occupation  hairstylist (e.g., plaiting hair, manicure, ma...
# 8826          occupation                                 carpentry, general
# ...                  ...                                                ...
# 38482         occupation  hairstylist (e.g., plaiting hair, manicure, ma...
# 38484         occupation  hairstylist (e.g., plaiting hair, manicure, ma...
# 38703             sports                      martial arts, different types
# 40587             sports               high ropes course, multiple elements
# 40588             sports               high ropes course, multiple elements
#
#        act_id
# 2191       47
# 3477      103
# 5243      378
# 7758      773
# 8826      899
# ...       ...
# 38482     773
# 38484     773
# 38703     775
# 40587     809
# 40588     809
#
# [233 rows x 81 columns]

# %%
# Check for images with full joint
train_df.query(" and ".join([f'(joint_{i}_id.notna())' for i in range(16)]))
# Out:
#        imgidx          image  frame_sec  vididx  is_train  ridx     x1  \
# 5           4  015601864.jpg         11    1660         1     0  627.0
# 6           4  015601864.jpg         11    1660         1     1  841.0
# 10          6  005808361.jpg        135    2462         1     0  914.0
# 11          6  005808361.jpg        135    2462         1     1  427.0
# 12          7  086617615.jpg        240    2462         1     0  252.0
# ...       ...            ...        ...     ...       ...   ...    ...
# 40928   24982  072772110.jpg        121    1587         1     0  506.0
# 40929   24983  039361034.jpg        135     793         1     0  406.0
# 40930   24984  084761779.jpg        158     793         1     0  287.0
# 40931   24984  084761779.jpg        158     793         1     1  333.0
# 40932   24984  084761779.jpg        158     793         1     2  400.0
#
#            x2     y1     y2  ...  joint_14_id  joint_14_is_visible  \
# 5       706.0  100.0  198.0  ...         14.0                  1.0
# 6       902.0  145.0  228.0  ...         14.0                  1.0
# 10     1031.0   79.0  237.0  ...         14.0                  1.0
# 11      549.0   66.0  221.0  ...         14.0                  1.0
# 12      331.0  187.0  266.0  ...         14.0                  1.0
# ...       ...    ...    ...  ...          ...                  ...
# 40928   548.0  305.0  351.0  ...         14.0                  1.0
# 40929   449.0  225.0  268.0  ...         14.0                  1.0
# 40930   324.0  130.0  163.0  ...         14.0                  0.0
# 40931   361.0  137.0  162.0  ...         14.0                  0.0
# 40932   428.0  140.0  168.0  ...         14.0                  0.0
#
#        joint_15_x  joint_15_y  joint_15_id  joint_15_is_visible   video_list  \
# 5           688.0       313.0         15.0                  1.0  aAOusnrSsHI
# 6           955.0       263.0         15.0                  1.0  aAOusnrSsHI
# 10         1142.0       478.0         15.0                  1.0  s1tES1dQA74
# 11          372.0       496.0         15.0                  1.0  s1tES1dQA74
# 12          362.0       346.0         15.0                  0.0  s1tES1dQA74
# ...           ...         ...          ...                  ...          ...
# 40928       461.0       414.0         15.0                  1.0  ZhfD22VSUho
# 40929       410.0       325.0         15.0                  1.0  GqxDyQ_TfZc
# 40930       268.0       194.0         15.0                  0.0  GqxDyQ_TfZc
# 40931       319.0       194.0         15.0                  0.0  GqxDyQ_TfZc
# 40932       386.0       198.0         15.0                  0.0  GqxDyQ_TfZc
#
#              cat_name     act_name  act_id
# 5              sports      curling       1
# 6              sports      curling       1
# 10             sports      curling       1
# 11             sports      curling       1
# 12             sports      curling       1
# ...               ...          ...     ...
# 40928  transportation  pushing car     972
# 40929  transportation  pushing car     972
# 40930  transportation  pushing car     972
# 40931  transportation  pushing car     972
# 40932  transportation  pushing car     972
#
# [19919 rows x 81 columns]

# %% [markdown]
# ### Insights

# %% [markdown]
# First of all, let's dive into the joints' distribution.

# %%
_ = train_df.filter(
    regex="joint_[0-9]*_is_visible"
).notna().sum(axis=0).plot(
    kind="bar",
    figsize=(14, 4),
    title="Absolute distribution of visible number of joints per image across dataset"
)
# Out:
# <AxesSubplot:title={'center':'Absolute distribution of number of joints per image across dataset'}>

# %%
_ = train_df.filter(
    regex="joint_[0-9]*_id"
).notna().astype(int).sum(axis=0).plot(
    kind="bar", 
    figsize=(14, 4),
    title='Absolute distribution of number of joints per image across dataset')

# %% [markdown]
# It appears, the 8th and 9th indexed joint have a very low visibility rate.

# %%
# Compute Visibility Ratio
pd.DataFrame(
    (
        train_df.filter(
            regex="joint_[0-9]*_is_visible"
        ).clip(upper=1).sum().values / 
        train_df.filter(
            regex="joint_[0-9]*_id"
        ).notna().astype(int).sum().values *100),
    [f'joint_{i}' for i in range(16)], columns=['% of visibility']
)
# Out:
#           % of visibility
# joint_0         74.476484
# joint_1         79.005343
# joint_2         72.997306
# joint_3         73.169608
# joint_4         79.005094
# joint_5         74.533025
# joint_6         56.167260
# joint_7         57.452745
# joint_8          0.006975
# joint_9          0.006975
# joint_10        75.902391
# joint_11        78.437118
# joint_12        78.648874
# joint_13        77.541018
# joint_14        77.080934
# joint_15        74.484211

# %% [markdown]
# Let's focus now on the statistics of visible joints per image

# %%
# For Visible Joints
print("#Joints/Image MEDIAN:",train_df[[f'joint_{i}_is_visible' for i in range(16)]].sum(axis=1).median())
print("#Joints/Image MEAN:",train_df[[f'joint_{i}_is_visible' for i in range(16)]].sum(axis=1).mean())
print("#Joints/Image STD:",train_df[[f'joint_{i}_is_visible' for i in range(16)]].sum(axis=1).std())
# Out:
# #Joints/Image MEDIAN: 10.0
# #Joints/Image MEAN: 9.456209644181893
# #Joints/Image STD: 3.1274884225125033

# %%
# For Joints
print("#Joints/Image MEDIAN:",train_df[[f'joint_{i}_id' for i in range(16)]].notna().astype(int).sum(axis=1).median())
print("#Joints/Image MEAN:",train_df[[f'joint_{i}_id' for i in range(16)]].notna().astype(int).sum(axis=1).mean())
print("#Joints/Image STD:",train_df[[f'joint_{i}_id' for i in range(16)]].notna().astype(int).sum(axis=1).std())
# Out:
# #Joints/Image MEDIAN: 16.0
# #Joints/Image MEAN: 14.861072949580986
# #Joints/Image STD: 2.2256605383368426

# %%
analysis_df = train_df[
    [f'joint_{i}_id' for i in range(16)]
].notna().astype(int).sum(axis=0).reset_index().rename(
    columns={'index':'joint', 0:'n_joints'}
)
analysis_df = analysis_df.assign(
    joint = analysis_df.joint.str.split('_').str[:2].str.join('_').map(dict(zip([f'joint_{i}'for i in range(16)], CFG.dataset.description.joints.names)))
).set_index('joint')

#.plot(linestyle='', figsize=(15, 6), marker='+', )
analysis_visible_df = train_df[
    [f'joint_{i}_is_visible' for i in range(16)]
].sum(axis=0).reset_index().rename(
    columns={'index':'joint', 0:'n_joints_visible'}
)
analysis_visible_df = analysis_visible_df.assign(
    joint = analysis_visible_df.joint.str.split('_').str[:2].str.join('_').map(dict(zip([f'joint_{i}'for i in range(16)], CFG.dataset.description.joints.names)))
).set_index('joint')

analysis_df = analysis_df.merge(analysis_visible_df, on='joint')
_ = analysis_df.plot(title='Number of present/visible data point per joint type',linestyle='', figsize=(15, 6), marker='+', markeredgewidth=3)

# %% [markdown]
# From the previous analysis, we observe the `upperNeck` and `topHead` joints have a low visibility rate. We cannot use the visibility information to build our dataset.

# %%
train_df = train_df.assign(
    available_joints=train_df.filter(regex="joint_[0-9]*_x").notna().astype(int).sum(axis=1)
)
train_df.filter(['imgidx', 'image','ridx', 'available_joints'])
# Out:
#        imgidx          image  ridx  available_joints
# 5           4  015601864.jpg     0                16
# 6           4  015601864.jpg     1                16
# 7           5  015599452.jpg     0                12
# 8           5  015599452.jpg     1                12
# 9           5  015599452.jpg     2                11
# ...       ...            ...   ...               ...
# 40930   24984  084761779.jpg     0                16
# 40931   24984  084761779.jpg     1                16
# 40932   24984  084761779.jpg     2                16
# 40933   24984  084761779.jpg     3                14
# 40934   24984  084761779.jpg     4                 6
#
# [29116 rows x 4 columns]

# %% [markdown]
# ## Generate Input/Output

# %% [markdown]
# From the train_df dataset we will use the following data:
# - `image`: image name
# - `joint_<JOINT_ID>_x`: joint JOINT_ID x coordinate
# - `joint_<JOINT_ID>_y`: joint JOINT_ID y coordinate

# %% [markdown]
# ### Numpy Implementation

# %% [markdown]
# #### Heatmap Generation

# %% [markdown]
# To describe our heatmap generation process we'll try to implement our preprocessing steps with Numpy

# %%
sample_df = train_df.query('13 <= available_joints <= 15').sample()
sample_df
# Out:
#        imgidx          image  frame_sec  vididx  is_train  ridx     x1     x2  \
# 38555   23886  037598667.jpg        171     580         1     2  232.0  325.0
#
#         y1    y2  ...  joint_14_is_visible  joint_15_x  joint_15_y  \
# 38555  1.0  77.0  ...                  0.0       406.0       311.0
#
#        joint_15_id  joint_15_is_visible   video_list     cat_name  \
# 38555         15.0                  1.0  BtlvL-U1IBY  home repair
#
#                          act_name  act_id  available_joints
# 38555  carpentry, sawing hardwood     774                14
#
# [1 rows x 82 columns]

# %% [markdown]
# We plot our sample image

# %%
img = imread(os.path.join(ROOT_FOLDER, DATA_FOLDER, IMAGE_FOLDER,sample_df.image.iloc[0]))
plt.figure(figsize=(12,7))
plt.imshow(img)
plt.grid(b=None)

# %%
sample_df.filter(regex="joint_[0-9]*_(x|y)")
# Out:
#        joint_0_x  joint_0_y  joint_1_x  joint_1_y  joint_2_x  joint_2_y  \
# 38555        NaN        NaN      392.0      509.0      271.0      354.0
#
#        joint_3_x  joint_3_y  joint_4_x  joint_4_y  ...  joint_11_x  \
# 38555      231.0      349.0      238.0      549.0  ...       246.0
#
#        joint_11_y  joint_12_x  joint_12_y  joint_13_x  joint_13_y  joint_14_x  \
# 38555       266.0       247.0       119.0       246.0       115.0       295.0
#
#        joint_14_y  joint_15_x  joint_15_y
# 38555       263.0       406.0       311.0
#
# [1 rows x 32 columns]

# %% [markdown]
# We generate the first heatmap for the `rWrist`

# %%
plt.figure(figsize=(12,7))
sample_heatmap = generate_joint_gaussian(img, sample_df.joint_10_x.iloc[0], sample_df.joint_10_y.iloc[0], sx=10, sy=10)
normalized_heatmap = (sample_heatmap / sample_heatmap.max())
plt.imshow(sample_heatmap)
plt.grid(b=None)

# %% [markdown]
# By superposing our heatmap to the input image we check if the heatmap is relevant

# %%
plt.figure(figsize=(12,7))
plt.imshow((np.expand_dims((normalized_heatmap * 255).astype(np.uint8), axis=-1)/255.0 + img/510.0))
plt.grid(b=None)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# We are now able to generate heatmaps for single joint. We can appkly this function to all the joint to compute the complete heatmap

# %%
# Let's compute the joint dictionnary `sample_joints` (Dict[str, Point(x, y)])
sample_df.filter(regex="joint_[0-9]*_(x|y)").iloc[0]
sample_joints = {f'joint_{k}':{} for k in range(16)}
_ = [sample_joints["_".join(k.split('_')[:-1])].update({k.split('_')[-1]:v})  for k, v in sample_df.filter(regex="joint_[0-9]*_(x|y)").iloc[0].to_dict().items()]
sample_joints
# Out:
# {'joint_0': {'x': nan, 'y': nan},
#  'joint_1': {'x': 392.0, 'y': 509.0},
#  'joint_2': {'x': 271.0, 'y': 354.0},
#  'joint_3': {'x': 231.0, 'y': 349.0},
#  'joint_4': {'x': 238.0, 'y': 549.0},
#  'joint_5': {'x': nan, 'y': nan},
#  'joint_6': {'x': 251.0, 'y': 352.0},
#  'joint_7': {'x': 247.0, 'y': 117.0},
#  'joint_8': {'x': 260.5102, 'y': 83.5462},
#  'joint_9': {'x': 296.4898, 'y': -5.5462},
#  'joint_10': {'x': 373.0, 'y': 328.0},
#  'joint_11': {'x': 246.0, 'y': 266.0},
#  'joint_12': {'x': 247.0, 'y': 119.0},
#  'joint_13': {'x': 246.0, 'y': 115.0},
#  'joint_14': {'x': 295.0, 'y': 263.0},
#  'joint_15': {'x': 406.0, 'y': 311.0}}

# %% [markdown]
# We can plot the full heatmap for the person's body

# %%
sample_heatmaps = np.stack([generate_joint_gaussian(img, **v, sx=10, sy=10) for k,v in sample_joints.items()])
len(sample_heatmaps)
plot_hVSimg(img, sample_heatmaps, factor=3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### Reshaping image

# %% [markdown]
# To fit our `inputSize` requirements we need to reshape the input image and to fit the output limitation, generated heatmaps should have a size of `outputSize`

# %%
print("Network Input Size:",CFG.data.input_size)
print("Network Output Size:",CFG.data.output_size)
# Out:
# Network Input Size: 256
# Network Output Size: 64

# %% [markdown]
# If we try to apply a straight reshaping, we cannot ensure the reshaped image will keep the input ratio. This could prevent our CNN to grasp body proportions.
#
# We'll complexify a bit our preprocessing by keeping the initial image ratio
#
# To keep the ratio, we use the largest dimension $D$, the dimension $D$ is now the dimension that will be reduced to `inputSize`, we can use **zero padding** to fill the lowest dimension $d$

# %%
# To keep the ratio we use the largest dimension D, the dimension 
largest_dimension_index = np.argmax(img.shape[:-1])
D, d = img.shape[largest_dimension_index], img.shape[int(not(largest_dimension_index))] 
padding = (D-d)//2
if largest_dimension_index:
    padding_array = [[padding, padding], [0, 0], [0, 0]]
else:
    padding_array = [[0, 0], [padding, padding], [0, 0]]
padded_img = np.pad(img, padding_array)
padded_hm = np.pad(sample_heatmaps, [[0, 0]] + padding_array[:-1])
plot_hVSimg(padded_img, padded_hm, factor=3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print("Image shape across preprocessing")
print("Initial shape:\t",img.shape)
print("Padded shape:\t",padded_img.shape)
print("Final shape:\t",resize(padded_img, (CFG.data.input_size, CFG.data.input_size)).shape)
# Out:
# Image shape across preprocessing
# Initial shape:	 (1080, 1920, 3)
# Padded shape:	 (1920, 1920, 3)
# Final shape:	 (256, 256, 3)

# %%
resized_hm = np.array(
    list(
        map(
            lambda x: resize(
                x, 
                (CFG.data.output_size, CFG.data.output_size)
            ),
            padded_hm)
    )
)
resized_hm.shape
# Out:
# (16, 64, 64)

# %% [markdown]
# Our main preprocessing steps are now defined, let's check the computation time

# %%
# %%timeit
for i in range(10):
    forced_img_name = '034809559.jpg'
    img = imread(os.path.join(ROOT_FOLDER, DATA_FOLDER, IMAGE_FOLDER,forced_img_name))

    sample_df = train_df.query(f'image == "{forced_img_name}"')

    sample_joints = {f'joint_{k}':{} for k in range(16)}
    _ = [sample_joints["_".join(k.split('_')[:-1])].update({k.split('_')[-1]:v})  for k, v in sample_df.filter(regex="joint_[0-9]*_(x|y)").iloc[0].to_dict().items()]
    sample_heatmaps = np.stack([generate_joint_gaussian(img, **v, sx=10, sy=10) for k,v in sample_joints.items()])
    largest_dimension_index = np.argmax(img.shape[:-1])
    D, d = img.shape[largest_dimension_index], img.shape[int(not(largest_dimension_index))] 
    padding = (D-d)//2
    if largest_dimension_index:
        padding_array = [[padding, padding], [0, 0], [0, 0]]
    else:
        padding_array = [[0, 0], [padding, padding], [0, 0]]
    padded_img = np.pad(img, padding_array)
    padded_hm = np.pad(sample_heatmaps, [[0, 0]] + padding_array[:-1])


    processed_img = resize(padded_img, (CFG.data.input_size, CFG.data.input_size))
    processed_hm = resized_hm = np.array(
        list(
            map(
                lambda x: resize(
                    x, 
                    (CFG.data.output_size, CFG.data.output_size)
                ),
                padded_hm)
        )
    )
# Out:
# 5.41 s ± 29.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# On 10 runs, the preprocessing stage took an average 541 ms per image, which is very slow regarding the number of images and the variance in image's shape. There are obvious improvement to make, but so far we try to illustrate the preprocessng step. We'll explain the possible improvements later.

# %% [markdown]
# ### Tensorflow Implementation

# %% [markdown]
# #### Loading & Heatmap generating functions

# %%
# Generates Input Data
filenames = (os.path.join(ROOT_FOLDER, DATA_FOLDER, IMAGE_FOLDER) + '/' + train_df.filter(regex="image")).image.tolist()
coordinates = train_df.filter(regex="joint_[0-9]*_(x|y)").values.reshape((-1, 16, 2))
#shapes = train_df.filter(['width', 'height']).values

# %%
# Create TF Dataset
dataset = tf.data.Dataset.from_tensor_slices(
    (filenames, coordinates)
).map(tf_parse_dataset).map(tf_preprocess)
dataset
# Out:
# <MapDataset shapes: ((256, 256, 3), (64, 64, 16)), types: (tf.float32, tf.float32)>

# %%
INDEX = 5
for tfsample in dataset.take(INDEX):
    pass
plot_hVSimg(
    tfsample[0].numpy(), 
    tf.transpose(tf.image.resize(tfsample[1], [256, 256]), [2, 0, 1]).numpy(),
    factor=2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Conclusion

# %% [markdown]
# As described in this notebook, we created a preprocessing pipeline to generate input and output data from raw images and the Dataset created in our first notebook.
#
# We also replicated our Numpy workflow with Tensorflow. The machine used for this notebook has no GPU, thus explaining the high processing time for a single image with TF.
#
# **NB:**
#
# We can provide an obvious criticism about our processing. As shown in the image above, we use images with multiple person as **input** and a single person ground truth as **output**. We can evidently assume this processing will bias the model by confusing it's learning.
#
#     e.g:
#         Let's define an image $I(HxW), with $P person with joint coordinates (n in [0, P-1] -> x_i:n, y_i:n)
#         For $I our model might output the correct body joint for a person X, our ground truth being for person Y.
#         In this case, our model's loss function will indicate to the model it was wrong even if the prediction was perfect.
#
# We can define more suitable preprocessing pipelines.
#
# **Exemple #1: Single Person Input**
# - Get an Image I
# - For person p on P people
#     - Get p bounding box
#     - Crop p
#     - Offset the joints with the top-left bbox corner
#     - Generate the heatmap on the cropped image
#     - Apply zero-padding to have a square shaped image
#     - Resize to the desired input size
#     - Add the resulting image to your dataset
#
# **Exemple #2: Multiple Person Input**
# - Get an Image I
# - Generate the Heatmap for each person and sum it (1 layers per body joint)
# - Apply passing and Resize to have a squared image
#
# This second workflow slighty modifies the task. The model will not be a Human Pose Estimator but rather a Body Joint detector. A second model should be in charge of reconciliating the infered body joints for a single person (Possible with Graph Model and raw programmatic logic)
